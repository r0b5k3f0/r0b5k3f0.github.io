# %% [markdown]
# # r0b5k3f0 JupyterLite
#
# 這是部署在 GitHub Pages 上的純靜態 JupyterLab。Python kernel 由 Pyodide 在瀏覽器內執行，不需要後端伺服器。
#
# Try running the next cell.

# %%
import sys, math, statistics
print('Hello from Python', sys.version.split()[0])
values = [3, 8, 13, 21, 34]
print('mean =', statistics.mean(values))
print('sqrt(2026) =', round(math.sqrt(2026), 4))

# %% [markdown]
# ## Matplotlib example
# If matplotlib is available, the following cell will draw a chart.

# %%
import micropip
await micropip.install('matplotlib')
import matplotlib.pyplot as plt
xs = list(range(12))
ys = [x*x for x in xs]
plt.figure(figsize=(6, 3))
plt.plot(xs, ys, marker='o')
plt.title('Pyodide Matplotlib in JupyterLite')
plt.grid(alpha=.25)
plt.show()
